# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# %%
results=pd.read_csv('C:\\Users\\bhuva\\OneDrive\\Desktop\\Python_P\\Datasets\\F1 Analytics\\results.csv')

# %%
races=pd.read_csv('C:\\Users\\bhuva\\OneDrive\\Desktop\\Python_P\\Datasets\\F1 Analytics\\races.csv')
drivers=pd.read_csv('C:\\Users\\bhuva\\OneDrive\\Desktop\\Python_P\\Datasets\\F1 Analytics\\drivers.csv')
constructors=pd.read_csv('C:\\Users\\bhuva\\OneDrive\\Desktop\\Python_P\\Datasets\\F1 Analytics\\constructors.csv')

# %%
df=pd.merge(results,races[['raceId','year','name','round']],on='raceId',how='left')

# %%
df=pd.merge(df,drivers[['driverId','driverRef','nationality']],on='driverId',how='left')
df=pd.merge(df,constructors[['constructorId','constructorRef','name','nationality']],on='constructorId',how='left')

# %%
df
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 25835     25841    1096       854            210     47    12       16
# 25836     25842    1096       825            210     20    16       17
# 25837     25843    1096         1            131     44     5       18
# 25838     25844    1096       849              3      6    20       19
# 25839     25845    1096         4            214     14    10       \N
#
#       positionText  positionOrder  points  ...  fastestLapSpeed statusId  \
# 0                1              1    10.0  ...          218.300        1
# 1                2              2     8.0  ...          217.586        1
# 2                3              3     6.0  ...          216.719        1
# 3                4              4     5.0  ...          215.464        1
# 4                5              5     4.0  ...          218.385        1
# ...            ...            ...     ...  ...              ...      ...
# 25835           16             16     0.0  ...          211.632       11
# 25836           17             17     0.0  ...          208.556       11
# 25837           18             18     0.0  ...          211.738        6
# 25838           19             19     0.0  ...          210.517      130
# 25839            R             20     0.0  ...          209.889       47
#
#        year                 name_x round        driverRef nationality_x  \
# 0      2008  Australian Grand Prix     1         hamilton       British
# 1      2008  Australian Grand Prix     1         heidfeld        German
# 2      2008  Australian Grand Prix     1          rosberg        German
# 3      2008  Australian Grand Prix     1           alonso       Spanish
# 4      2008  Australian Grand Prix     1       kovalainen       Finnish
# ...     ...                    ...   ...              ...           ...
# 25835  2022   Abu Dhabi Grand Prix    22  mick_schumacher        German
# 25836  2022   Abu Dhabi Grand Prix    22  kevin_magnussen        Danish
# 25837  2022   Abu Dhabi Grand Prix    22         hamilton       British
# 25838  2022   Abu Dhabi Grand Prix    22           latifi      Canadian
# 25839  2022   Abu Dhabi Grand Prix    22           alonso       Spanish
#
#        constructorRef          name_y nationality_y
# 0             mclaren         McLaren       British
# 1          bmw_sauber      BMW Sauber        German
# 2            williams        Williams       British
# 3             renault         Renault        French
# 4             mclaren         McLaren       British
# ...               ...             ...           ...
# 25835            haas    Haas F1 Team      American
# 25836            haas    Haas F1 Team      American
# 25837        mercedes        Mercedes        German
# 25838        williams        Williams       British
# 25839          alpine  Alpine F1 Team        French
#
# [25840 rows x 26 columns]

# %%
df.drop(['number','position','positionText','laps','fastestLap','statusId','resultId','raceId','driverId','constructorId'],axis=1,inplace=True)

# %%
df.rename(columns={'rank':'fastestLapRank','name_x':'gpName','nationality_x':'driverNationality','name_y':'constructorName','nationality_y':'constructorNationality','driverRef':'driver'},inplace=True)

# %%
df
# Out:
#        grid  positionOrder  points         time milliseconds fastestLapRank  \
# 0         1              1    10.0  1:34:50.616      5690616              2
# 1         5              2     8.0       +5.478      5696094              3
# 2         7              3     6.0       +8.163      5698779              5
# 3        11              4     5.0      +17.181      5707797              7
# 4         3              5     4.0      +18.014      5708630              1
# ...     ...            ...     ...          ...          ...            ...
# 25835    12             16     0.0           \N           \N             12
# 25836    16             17     0.0           \N           \N             20
# 25837     5             18     0.0           \N           \N             11
# 25838    20             19     0.0           \N           \N             14
# 25839    10             20     0.0           \N           \N             17
#
#       fastestLapTime fastestLapSpeed  year                 gpName  round  \
# 0           1:27.452         218.300  2008  Australian Grand Prix      1
# 1           1:27.739         217.586  2008  Australian Grand Prix      1
# 2           1:28.090         216.719  2008  Australian Grand Prix      1
# 3           1:28.603         215.464  2008  Australian Grand Prix      1
# 4           1:27.418         218.385  2008  Australian Grand Prix      1
# ...              ...             ...   ...                    ...    ...
# 25835       1:29.833         211.632  2022   Abu Dhabi Grand Prix     22
# 25836       1:31.158         208.556  2022   Abu Dhabi Grand Prix     22
# 25837       1:29.788         211.738  2022   Abu Dhabi Grand Prix     22
# 25838       1:30.309         210.517  2022   Abu Dhabi Grand Prix     22
# 25839       1:30.579         209.889  2022   Abu Dhabi Grand Prix     22
#
#                 driver driverNationality constructorRef constructorName  \
# 0             hamilton           British        mclaren         McLaren
# 1             heidfeld            German     bmw_sauber      BMW Sauber
# 2              rosberg            German       williams        Williams
# 3               alonso           Spanish        renault         Renault
# 4           kovalainen           Finnish        mclaren         McLaren
# ...                ...               ...            ...             ...
# 25835  mick_schumacher            German           haas    Haas F1 Team
# 25836  kevin_magnussen            Danish           haas    Haas F1 Team
# 25837         hamilton           British       mercedes        Mercedes
# 25838           latifi          Canadian       williams        Williams
# 25839           alonso           Spanish         alpine  Alpine F1 Team
#
#       constructorNationality
# 0                    British
# 1                     German
# 2                    British
# 3                     French
# 4                    British
# ...                      ...
# 25835               American
# 25836               American
# 25837                 German
# 25838                British
# 25839                 French
#
# [25840 rows x 16 columns]

# %%
df=df[['year','gpName','round','driver','constructorName','grid','positionOrder','points','time','milliseconds','fastestLapRank','fastestLapTime','fastestLapSpeed','driverNationality','constructorNationality']]

# %%
df
# Out:
#        year                 gpName  round           driver constructorName  \
# 0      2008  Australian Grand Prix      1         hamilton         McLaren
# 1      2008  Australian Grand Prix      1         heidfeld      BMW Sauber
# 2      2008  Australian Grand Prix      1          rosberg        Williams
# 3      2008  Australian Grand Prix      1           alonso         Renault
# 4      2008  Australian Grand Prix      1       kovalainen         McLaren
# ...     ...                    ...    ...              ...             ...
# 25835  2022   Abu Dhabi Grand Prix     22  mick_schumacher    Haas F1 Team
# 25836  2022   Abu Dhabi Grand Prix     22  kevin_magnussen    Haas F1 Team
# 25837  2022   Abu Dhabi Grand Prix     22         hamilton        Mercedes
# 25838  2022   Abu Dhabi Grand Prix     22           latifi        Williams
# 25839  2022   Abu Dhabi Grand Prix     22           alonso  Alpine F1 Team
#
#        grid  positionOrder  points         time milliseconds fastestLapRank  \
# 0         1              1    10.0  1:34:50.616      5690616              2
# 1         5              2     8.0       +5.478      5696094              3
# 2         7              3     6.0       +8.163      5698779              5
# 3        11              4     5.0      +17.181      5707797              7
# 4         3              5     4.0      +18.014      5708630              1
# ...     ...            ...     ...          ...          ...            ...
# 25835    12             16     0.0           \N           \N             12
# 25836    16             17     0.0           \N           \N             20
# 25837     5             18     0.0           \N           \N             11
# 25838    20             19     0.0           \N           \N             14
# 25839    10             20     0.0           \N           \N             17
#
#       fastestLapTime fastestLapSpeed driverNationality constructorNationality
# 0           1:27.452         218.300           British                British
# 1           1:27.739         217.586            German                 German
# 2           1:28.090         216.719            German                British
# 3           1:28.603         215.464           Spanish                 French
# 4           1:27.418         218.385           Finnish                British
# ...              ...             ...               ...                    ...
# 25835       1:29.833         211.632            German               American
# 25836       1:31.158         208.556            Danish               American
# 25837       1:29.788         211.738           British                 German
# 25838       1:30.309         210.517          Canadian                British
# 25839       1:30.579         209.889           Spanish                 French
#
# [25840 rows x 15 columns]

# %%
 df=df[df['year']!=2019]

# %%
df
# Out:
#        year                 gpName  round           driver constructorName  \
# 0      2008  Australian Grand Prix      1         hamilton         McLaren
# 1      2008  Australian Grand Prix      1         heidfeld      BMW Sauber
# 2      2008  Australian Grand Prix      1          rosberg        Williams
# 3      2008  Australian Grand Prix      1           alonso         Renault
# 4      2008  Australian Grand Prix      1       kovalainen         McLaren
# ...     ...                    ...    ...              ...             ...
# 25835  2022   Abu Dhabi Grand Prix     22  mick_schumacher    Haas F1 Team
# 25836  2022   Abu Dhabi Grand Prix     22  kevin_magnussen    Haas F1 Team
# 25837  2022   Abu Dhabi Grand Prix     22         hamilton        Mercedes
# 25838  2022   Abu Dhabi Grand Prix     22           latifi        Williams
# 25839  2022   Abu Dhabi Grand Prix     22           alonso  Alpine F1 Team
#
#        grid  positionOrder  points         time milliseconds fastestLapRank  \
# 0         1              1    10.0  1:34:50.616      5690616              2
# 1         5              2     8.0       +5.478      5696094              3
# 2         7              3     6.0       +8.163      5698779              5
# 3        11              4     5.0      +17.181      5707797              7
# 4         3              5     4.0      +18.014      5708630              1
# ...     ...            ...     ...          ...          ...            ...
# 25835    12             16     0.0           \N           \N             12
# 25836    16             17     0.0           \N           \N             20
# 25837     5             18     0.0           \N           \N             11
# 25838    20             19     0.0           \N           \N             14
# 25839    10             20     0.0           \N           \N             17
#
#       fastestLapTime fastestLapSpeed driverNationality constructorNationality
# 0           1:27.452         218.300           British                British
# 1           1:27.739         217.586            German                 German
# 2           1:28.090         216.719            German                British
# 3           1:28.603         215.464           Spanish                 French
# 4           1:27.418         218.385           Finnish                British
# ...              ...             ...               ...                    ...
# 25835       1:29.833         211.632            German               American
# 25836       1:31.158         208.556            Danish               American
# 25837       1:29.788         211.738           British                 German
# 25838       1:30.309         210.517          Canadian                British
# 25839       1:30.579         209.889           Spanish                 French
#
# [25420 rows x 15 columns]

# %%
df=df.sort_values(by=['year','round','positionOrder'],ascending=[False,True,True])

# %%
df
# Out:
#        year              gpName  round           driver constructorName  grid  \
# 25400  2022  Bahrain Grand Prix      1          leclerc         Ferrari     1
# 25401  2022  Bahrain Grand Prix      1            sainz         Ferrari     3
# 25402  2022  Bahrain Grand Prix      1         hamilton        Mercedes     5
# 25403  2022  Bahrain Grand Prix      1          russell        Mercedes     9
# 25404  2022  Bahrain Grand Prix      1  kevin_magnussen    Haas F1 Team     7
# ...     ...                 ...    ...              ...             ...   ...
# 20171  1950  Italian Grand Prix      7           sanesi      Alfa Romeo     4
# 20172  1950  Italian Grand Prix      7           manzon           Simca    10
# 20173  1950  Italian Grand Prix      7             bira        Maserati    15
# 20174  1950  Italian Grand Prix      7          pietsch        Maserati    27
# 20175  1950  Italian Grand Prix      7          bonetto          Milano    23
#
#        positionOrder  points         time milliseconds fastestLapRank  \
# 25400              1    26.0  1:37:33.584      5853584              1
# 25401              2    18.0       +5.598      5859182              3
# 25402              3    15.0       +9.675      5863259              5
# 25403              4    12.0      +11.211      5864795              6
# 25404              5    10.0      +14.754      5868338              8
# ...              ...     ...          ...          ...            ...
# 20171             23     0.0           \N           \N             \N
# 20172             24     0.0           \N           \N             \N
# 20173             25     0.0           \N           \N             \N
# 20174             26     0.0           \N           \N             \N
# 20175             27     0.0           \N           \N             \N
#
#       fastestLapTime fastestLapSpeed driverNationality constructorNationality
# 25400       1:34.570         206.018        Monegasque                Italian
# 25401       1:35.740         203.501           Spanish                Italian
# 25402       1:36.228         202.469           British                 German
# 25403       1:36.302         202.313           British                 German
# 25404       1:36.623         201.641            Danish               American
# ...              ...             ...               ...                    ...
# 20171             \N              \N           Italian                  Swiss
# 20172             \N              \N            French                 French
# 20173             \N              \N              Thai                Italian
# 20174             \N              \N            German                Italian
# 20175             \N              \N           Italian                Italian
#
# [25420 rows x 15 columns]

# %%
df.time.replace('\\N',np.nan,inplace=True)

# %%
df
# Out:
#        year              gpName  round           driver constructorName  grid  \
# 25400  2022  Bahrain Grand Prix      1          leclerc         Ferrari     1
# 25401  2022  Bahrain Grand Prix      1            sainz         Ferrari     3
# 25402  2022  Bahrain Grand Prix      1         hamilton        Mercedes     5
# 25403  2022  Bahrain Grand Prix      1          russell        Mercedes     9
# 25404  2022  Bahrain Grand Prix      1  kevin_magnussen    Haas F1 Team     7
# ...     ...                 ...    ...              ...             ...   ...
# 20171  1950  Italian Grand Prix      7           sanesi      Alfa Romeo     4
# 20172  1950  Italian Grand Prix      7           manzon           Simca    10
# 20173  1950  Italian Grand Prix      7             bira        Maserati    15
# 20174  1950  Italian Grand Prix      7          pietsch        Maserati    27
# 20175  1950  Italian Grand Prix      7          bonetto          Milano    23
#
#        positionOrder  points         time milliseconds fastestLapRank  \
# 25400              1    26.0  1:37:33.584      5853584              1
# 25401              2    18.0       +5.598      5859182              3
# 25402              3    15.0       +9.675      5863259              5
# 25403              4    12.0      +11.211      5864795              6
# 25404              5    10.0      +14.754      5868338              8
# ...              ...     ...          ...          ...            ...
# 20171             23     0.0          NaN           \N             \N
# 20172             24     0.0          NaN           \N             \N
# 20173             25     0.0          NaN           \N             \N
# 20174             26     0.0          NaN           \N             \N
# 20175             27     0.0          NaN           \N             \N
#
#       fastestLapTime fastestLapSpeed driverNationality constructorNationality
# 25400       1:34.570         206.018        Monegasque                Italian
# 25401       1:35.740         203.501           Spanish                Italian
# 25402       1:36.228         202.469           British                 German
# 25403       1:36.302         202.313           British                 German
# 25404       1:36.623         201.641            Danish               American
# ...              ...             ...               ...                    ...
# 20171             \N              \N           Italian                  Swiss
# 20172             \N              \N            French                 French
# 20173             \N              \N              Thai                Italian
# 20174             \N              \N            German                Italian
# 20175             \N              \N           Italian                Italian
#
# [25420 rows x 15 columns]

# %%
df.milliseconds.replace('\\N',np.nan,inplace=True)
df.fastestLapRank.replace('\\N',np.nan,inplace=True)
df.fastestLapTime.replace('\\N',np.nan,inplace=True)
df.fastestLapSpeed.replace('\\N',np.nan,inplace=True)

# %%
df
# Out:
#        year              gpName  round           driver constructorName  grid  \
# 25400  2022  Bahrain Grand Prix      1          leclerc         Ferrari     1
# 25401  2022  Bahrain Grand Prix      1            sainz         Ferrari     3
# 25402  2022  Bahrain Grand Prix      1         hamilton        Mercedes     5
# 25403  2022  Bahrain Grand Prix      1          russell        Mercedes     9
# 25404  2022  Bahrain Grand Prix      1  kevin_magnussen    Haas F1 Team     7
# ...     ...                 ...    ...              ...             ...   ...
# 20171  1950  Italian Grand Prix      7           sanesi      Alfa Romeo     4
# 20172  1950  Italian Grand Prix      7           manzon           Simca    10
# 20173  1950  Italian Grand Prix      7             bira        Maserati    15
# 20174  1950  Italian Grand Prix      7          pietsch        Maserati    27
# 20175  1950  Italian Grand Prix      7          bonetto          Milano    23
#
#        positionOrder  points         time milliseconds fastestLapRank  \
# 25400              1    26.0  1:37:33.584      5853584              1
# 25401              2    18.0       +5.598      5859182              3
# 25402              3    15.0       +9.675      5863259              5
# 25403              4    12.0      +11.211      5864795              6
# 25404              5    10.0      +14.754      5868338              8
# ...              ...     ...          ...          ...            ...
# 20171             23     0.0          NaN          NaN            NaN
# 20172             24     0.0          NaN          NaN            NaN
# 20173             25     0.0          NaN          NaN            NaN
# 20174             26     0.0          NaN          NaN            NaN
# 20175             27     0.0          NaN          NaN            NaN
#
#       fastestLapTime fastestLapSpeed driverNationality constructorNationality
# 25400       1:34.570         206.018        Monegasque                Italian
# 25401       1:35.740         203.501           Spanish                Italian
# 25402       1:36.228         202.469           British                 German
# 25403       1:36.302         202.313           British                 German
# 25404       1:36.623         201.641            Danish               American
# ...              ...             ...               ...                    ...
# 20171            NaN             NaN           Italian                  Swiss
# 20172            NaN             NaN            French                 French
# 20173            NaN             NaN              Thai                Italian
# 20174            NaN             NaN            German                Italian
# 20175            NaN             NaN           Italian                Italian
#
# [25420 rows x 15 columns]

# %%
df.milliseconds=df.milliseconds.astype(float)

# %%
df.fastestLapRank=df.fastestLapRank.astype(float)
df.fastestLapSpeed=df.fastestLapSpeed.astype(float)

# %%
df
# Out:
#        year              gpName  round           driver constructorName  grid  \
# 25400  2022  Bahrain Grand Prix      1          leclerc         Ferrari     1
# 25401  2022  Bahrain Grand Prix      1            sainz         Ferrari     3
# 25402  2022  Bahrain Grand Prix      1         hamilton        Mercedes     5
# 25403  2022  Bahrain Grand Prix      1          russell        Mercedes     9
# 25404  2022  Bahrain Grand Prix      1  kevin_magnussen    Haas F1 Team     7
# ...     ...                 ...    ...              ...             ...   ...
# 20171  1950  Italian Grand Prix      7           sanesi      Alfa Romeo     4
# 20172  1950  Italian Grand Prix      7           manzon           Simca    10
# 20173  1950  Italian Grand Prix      7             bira        Maserati    15
# 20174  1950  Italian Grand Prix      7          pietsch        Maserati    27
# 20175  1950  Italian Grand Prix      7          bonetto          Milano    23
#
#        positionOrder  points         time  milliseconds  fastestLapRank  \
# 25400              1    26.0  1:37:33.584     5853584.0             1.0
# 25401              2    18.0       +5.598     5859182.0             3.0
# 25402              3    15.0       +9.675     5863259.0             5.0
# 25403              4    12.0      +11.211     5864795.0             6.0
# 25404              5    10.0      +14.754     5868338.0             8.0
# ...              ...     ...          ...           ...             ...
# 20171             23     0.0          NaN           NaN             NaN
# 20172             24     0.0          NaN           NaN             NaN
# 20173             25     0.0          NaN           NaN             NaN
# 20174             26     0.0          NaN           NaN             NaN
# 20175             27     0.0          NaN           NaN             NaN
#
#       fastestLapTime  fastestLapSpeed driverNationality constructorNationality
# 25400       1:34.570          206.018        Monegasque                Italian
# 25401       1:35.740          203.501           Spanish                Italian
# 25402       1:36.228          202.469           British                 German
# 25403       1:36.302          202.313           British                 German
# 25404       1:36.623          201.641            Danish               American
# ...              ...              ...               ...                    ...
# 20171            NaN              NaN           Italian                  Swiss
# 20172            NaN              NaN            French                 French
# 20173            NaN              NaN              Thai                Italian
# 20174            NaN              NaN            German                Italian
# 20175            NaN              NaN           Italian                Italian
#
# [25420 rows x 15 columns]

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#        year              gpName  round           driver constructorName  grid  \
# 0      2022  Bahrain Grand Prix      1          leclerc         Ferrari     1
# 1      2022  Bahrain Grand Prix      1            sainz         Ferrari     3
# 2      2022  Bahrain Grand Prix      1         hamilton        Mercedes     5
# 3      2022  Bahrain Grand Prix      1          russell        Mercedes     9
# 4      2022  Bahrain Grand Prix      1  kevin_magnussen    Haas F1 Team     7
# ...     ...                 ...    ...              ...             ...   ...
# 25415  1950  Italian Grand Prix      7           sanesi      Alfa Romeo     4
# 25416  1950  Italian Grand Prix      7           manzon           Simca    10
# 25417  1950  Italian Grand Prix      7             bira        Maserati    15
# 25418  1950  Italian Grand Prix      7          pietsch        Maserati    27
# 25419  1950  Italian Grand Prix      7          bonetto          Milano    23
#
#        positionOrder  points         time  milliseconds  fastestLapRank  \
# 0                  1    26.0  1:37:33.584     5853584.0             1.0
# 1                  2    18.0       +5.598     5859182.0             3.0
# 2                  3    15.0       +9.675     5863259.0             5.0
# 3                  4    12.0      +11.211     5864795.0             6.0
# 4                  5    10.0      +14.754     5868338.0             8.0
# ...              ...     ...          ...           ...             ...
# 25415             23     0.0          NaN           NaN             NaN
# 25416             24     0.0          NaN           NaN             NaN
# 25417             25     0.0          NaN           NaN             NaN
# 25418             26     0.0          NaN           NaN             NaN
# 25419             27     0.0          NaN           NaN             NaN
#
#       fastestLapTime  fastestLapSpeed driverNationality constructorNationality
# 0           1:34.570          206.018        Monegasque                Italian
# 1           1:35.740          203.501           Spanish                Italian
# 2           1:36.228          202.469           British                 German
# 3           1:36.302          202.313           British                 German
# 4           1:36.623          201.641            Danish               American
# ...              ...              ...               ...                    ...
# 25415            NaN              NaN           Italian                  Swiss
# 25416            NaN              NaN            French                 French
# 25417            NaN              NaN              Thai                Italian
# 25418            NaN              NaN            German                Italian
# 25419            NaN              NaN           Italian                Italian
#
# [25420 rows x 15 columns]

# %%
print(df.shape)
# Out:
# (25420, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25420 entries, 0 to 25419
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   year                    25420 non-null  int64
#  1   gpName                  25420 non-null  object
#  2   round                   25420 non-null  int64
#  3   driver                  25420 non-null  object
#  4   constructorName         25420 non-null  object
#  5   grid                    25420 non-null  int64
#  6   positionOrder           25420 non-null  int64
#  7   points                  25420 non-null  float64
#  8   time                    6892 non-null   object
#  9   milliseconds            6891 non-null   float64
#  10  fastestLapRank          7171 non-null   float64
#  11  fastestLapTime          6963 non-null   object
#  12  fastestLapSpeed         6963 non-null   float64
#  13  driverNationality       25420 non-null  object
#  14  constructorNationality  25420 non-null  object
# dtypes: float64(4), int64(4), object(7)
# memory usage: 2.9+ MB

# %%
df.head(20)
# Out:
#     year              gpName  round           driver constructorName  grid  \
# 0   2022  Bahrain Grand Prix      1          leclerc         Ferrari     1
# 1   2022  Bahrain Grand Prix      1            sainz         Ferrari     3
# 2   2022  Bahrain Grand Prix      1         hamilton        Mercedes     5
# 3   2022  Bahrain Grand Prix      1          russell        Mercedes     9
# 4   2022  Bahrain Grand Prix      1  kevin_magnussen    Haas F1 Team     7
# 5   2022  Bahrain Grand Prix      1           bottas      Alfa Romeo     6
# 6   2022  Bahrain Grand Prix      1             ocon  Alpine F1 Team    11
# 7   2022  Bahrain Grand Prix      1          tsunoda      AlphaTauri    16
# 8   2022  Bahrain Grand Prix      1           alonso  Alpine F1 Team     8
# 9   2022  Bahrain Grand Prix      1             zhou      Alfa Romeo    15
# 10  2022  Bahrain Grand Prix      1  mick_schumacher    Haas F1 Team    12
# 11  2022  Bahrain Grand Prix      1           stroll    Aston Martin    19
# 12  2022  Bahrain Grand Prix      1            albon        Williams    14
# 13  2022  Bahrain Grand Prix      1        ricciardo         McLaren    18
# 14  2022  Bahrain Grand Prix      1           norris         McLaren    13
# 15  2022  Bahrain Grand Prix      1           latifi        Williams    20
# 16  2022  Bahrain Grand Prix      1       hulkenberg    Aston Martin    17
# 17  2022  Bahrain Grand Prix      1            perez        Red Bull     4
# 18  2022  Bahrain Grand Prix      1   max_verstappen        Red Bull     2
# 19  2022  Bahrain Grand Prix      1            gasly      AlphaTauri    10
#
#     positionOrder  points         time  milliseconds  fastestLapRank  \
# 0               1    26.0  1:37:33.584     5853584.0             1.0
# 1               2    18.0       +5.598     5859182.0             3.0
# 2               3    15.0       +9.675     5863259.0             5.0
# 3               4    12.0      +11.211     5864795.0             6.0
# 4               5    10.0      +14.754     5868338.0             8.0
# 5               6     8.0      +16.119     5869703.0             7.0
# 6               7     6.0      +19.423     5873007.0            14.0
# 7               8     4.0      +20.386     5873970.0            13.0
# 8               9     2.0      +22.390     5875974.0            10.0
# 9              10     1.0      +23.064     5876648.0             9.0
# 10             11     0.0      +32.574     5886158.0            11.0
# 11             12     0.0      +45.873     5899457.0            15.0
# 12             13     0.0      +53.932     5907516.0            18.0
# 13             14     0.0      +54.975     5908559.0            16.0
# 14             15     0.0      +56.335     5909919.0            12.0
# 15             16     0.0    +1:01.795     5915379.0            20.0
# 16             17     0.0    +1:03.829     5917413.0            19.0
# 17             18     0.0          NaN           NaN             4.0
# 18             19     0.0          NaN           NaN             2.0
# 19             20     0.0          NaN           NaN            17.0
#
#    fastestLapTime  fastestLapSpeed driverNationality constructorNationality
# 0        1:34.570          206.018        Monegasque                Italian
# 1        1:35.740          203.501           Spanish                Italian
# 2        1:36.228          202.469           British                 German
# 3        1:36.302          202.313           British                 German
# 4        1:36.623          201.641            Danish               American
# 5        1:36.599          201.691           Finnish                  Swiss
# 6        1:37.110          200.630            French                 French
# 7        1:37.104          200.642          Japanese                Italian
# 8        1:36.733          201.412           Spanish                 French
# 9        1:36.685          201.512           Chinese                  Swiss
# 10       1:36.956          200.948            German               American
# 11       1:37.146          200.555          Canadian                British
# 12       1:37.355          200.125              Thai                British
# 13       1:37.261          200.318        Australian                British
# 14       1:36.988          200.882           British                British
# 15       1:38.251          198.300          Canadian                British
# 16       1:38.201          198.401            German                British
# 17       1:36.089          202.762           Mexican               Austrian
# 18       1:35.440          204.140             Dutch               Austrian
# 19       1:37.324          200.189            French                Italian

# %%
sb.set_palette('Set3')
plt.rcParams['figure.figsize']=10,6

# %%
driverWinner=df.loc[df['positionOrder']==1].groupby('driver')['positionOrder'].count().sort_values(ascending=False).to_frame().reset_index()

# %%
driverWinner
# Out:
#                  driver  positionOrder
# 0              hamilton             92
# 1    michael_schumacher             91
# 2                vettel             52
# 3                 prost             51
# 4                 senna             41
# ..                  ...            ...
# 108              kubica              1
# 109            rathmann              1
# 110             fagioli              1
# 111               alesi              1
# 112          kovalainen              1
#
# [113 rows x 2 columns]

# %%
sb.barplot(data=driverWinner,y='driver',x='positionOrder',color='red',alpha=0.9)
plt.title('Most Grand Prix Wins')
plt.xlabel('Number of wins')
plt.ylabel('Driver')
plt.yticks([])
# Out:
# ([], [])

# %%
top10Drivers=driverWinner.head(10)
print(top10Drivers)
# Out:
#                driver  positionOrder
# 0            hamilton             92
# 1  michael_schumacher             91
# 2              vettel             52
# 3               prost             51
# 4               senna             41
# 5              alonso             32
# 6      max_verstappen             32
# 7             mansell             31
# 8             stewart             27
# 9               clark             25

# %%
sb.barplot(data=top10Drivers,y='driver',x='positionOrder',color='green',alpha=0.9,linewidth=0.9,edgecolor='black')
plt.title('Most GP Wins')
plt.ylabel('Driver')
plt.xlabel('Number of wins')
plt.xticks(np.arange(0, 100, 10))
# Out:
# ([<matplotlib.axis.XTick at 0x2054d4f52d0>,
#   <matplotlib.axis.XTick at 0x2054d4f40d0>,
#   <matplotlib.axis.XTick at 0x2054d1d15d0>,
#   <matplotlib.axis.XTick at 0x2054d445690>,
#   <matplotlib.axis.XTick at 0x2054d444ad0>,
#   <matplotlib.axis.XTick at 0x2054d49a6d0>,
#   <matplotlib.axis.XTick at 0x2054d484810>,
#   <matplotlib.axis.XTick at 0x2054d18ee90>,
#   <matplotlib.axis.XTick at 0x2054d487f50>,
#   <matplotlib.axis.XTick at 0x2054d1b0690>],
#  [Text(0, 0, '0'),
#   Text(10, 0, '10'),
#   Text(20, 0, '20'),
#   Text(30, 0, '30'),
#   Text(40, 0, '40'),
#   Text(50, 0, '50'),
#   Text(60, 0, '60'),
#   Text(70, 0, '70'),
#   Text(80, 0, '80'),
#   Text(90, 0, '90')])

# %%
constructorWinner=df.loc[df['positionOrder']==1].groupby('constructorName')['positionOrder'].count().sort_values(ascending=False).to_frame().reset_index()

# %%
constructorWinner
# Out:
#     constructorName  positionOrder
# 0           Ferrari            240
# 1           McLaren            179
# 2          Williams            114
# 3          Mercedes            110
# 4          Red Bull             89
# 5        Team Lotus             45
# 6           Renault             35
# 7          Benetton             27
# 8           Brabham             23
# 9           Tyrrell             23
# 10     Lotus-Climax             22
# 11              BRM             17
# 12    Cooper-Climax             12
# 13       Lotus-Ford             11
# 14       Alfa Romeo             11
# 15          Vanwall             10
# 16       Matra-Ford              9
# 17           Ligier              9
# 18         Maserati              9
# 19            Brawn              8
# 20    Brabham-Repco              8
# 21     Kurtis Kraft              5
# 22     McLaren-Ford              4
# 23           Jordan              4
# 24           Watson              3
# 25            March              3
# 26             Wolf              3
# 27            Honda              3
# 28  Cooper-Maserati              2
# 29           Cooper              2
# 30   Brabham-Climax              2
# 31     Brabham-Ford              2
# 32         Lotus F1              2
# 33          Epperly              2
# 34           Penske              1
# 35          Porsche              1
# 36     Racing Point              1
# 37    Eagle-Weslake              1
# 38       AlphaTauri              1
# 39           Shadow              1
# 40          Stewart              1
# 41       Toro Rosso              1
# 42          Hesketh              1
# 43            Kuzma              1
# 44       BMW Sauber              1
# 45   Alpine F1 Team              1
# 46        Lotus-BRM              1

# %%
sb.barplot(data=constructorWinner,x='positionOrder',y='constructorName',color='green',edgecolor='black')
plt.title('Constructor most wins')
plt.xlabel('Number of wins')
plt.ylabel('Constructor')
plt.yticks([])
# Out:
# ([], [])

# %%
top10Constructors=constructorWinner.head(10)

# %%
top10Constructors
# Out:
#   constructorName  positionOrder
# 0         Ferrari            240
# 1         McLaren            179
# 2        Williams            114
# 3        Mercedes            110
# 4        Red Bull             89
# 5      Team Lotus             45
# 6         Renault             35
# 7        Benetton             27
# 8         Brabham             23
# 9         Tyrrell             23

# %%
sb.barplot(data=top10Constructors,x='positionOrder',y='constructorName',color='blue',edgecolor='black')
plt.title('Top 10 Constructors')
plt.xlabel('Number of wins')
plt.ylabel('Constrcutor')
plt.xticks(np.arange(20,240,40))
# Out:
# ([<matplotlib.axis.XTick at 0x2054d4ae990>,
#   <matplotlib.axis.XTick at 0x2054d462a10>,
#   <matplotlib.axis.XTick at 0x2054d066710>,
#   <matplotlib.axis.XTick at 0x2054d1c1f50>,
#   <matplotlib.axis.XTick at 0x2054d032450>,
#   <matplotlib.axis.XTick at 0x2054d0e8450>],
#  [Text(20, 0, '20'),
#   Text(60, 0, '60'),
#   Text(100, 0, '100'),
#   Text(140, 0, '140'),
#   Text(180, 0, '180'),
#   Text(220, 0, '220')])
